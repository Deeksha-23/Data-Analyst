# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np

# %%
df = pd.read_csv("global_emissions.csv")

# %%
df.head()
# Out:
#    Year Country.Name Country.Code   Country.GDP  Country.Population  \
# 0  1992  Afghanistan          AFG  1.267754e+10            14485543
# 1  1993  Afghanistan          AFG  9.834581e+09            15816601
# 2  1994  Afghanistan          AFG  7.919857e+09            17075728
# 3  1995  Afghanistan          AFG  1.230753e+10            18110662
# 4  1996  Afghanistan          AFG  1.207013e+10            18853444
#
#    Emissions.Production.CH4  Emissions.Production.N2O  \
# 0                      7.13                      2.89
# 1                      7.21                      2.93
# 2                      7.47                      2.76
# 3                      7.83                      2.88
# 4                      8.67                      3.12
#
#    Emissions.Production.CO2.Cement  Emissions.Production.CO2.Coal  \
# 0                            0.046                          0.022
# 1                            0.047                          0.018
# ...

# %%
df.tail()
# Out:
#       Year Country.Name Country.Code   Country.GDP  Country.Population  \
# 2479  2014      Vietnam          VNM  5.098024e+11            91713848
# 2480  2015      Vietnam          VNM  5.439311e+11            92677080
# 2481  2016      Vietnam          VNM  5.776835e+11            93640440
# 2482  2017      Vietnam          VNM  6.177747e+11            94600640
# 2483  2018      Vietnam          VNM  6.614884e+11            95545960
#
#       Emissions.Production.CH4  Emissions.Production.N2O  \
# 2479                     84.93                     23.48
# 2480                     83.85                     25.91
# 2481                     81.85                     24.82
# 2482                     81.28                     24.89
# 2483                     81.42                     25.44
#
#       Emissions.Production.CO2.Cement  Emissions.Production.CO2.Coal  \
# 2479                           32.694                         70.517
# ...

# %%
df.describe()
# Out:
#               Year   Country.GDP  Country.Population  \
# count  2484.000000  2.484000e+03        2.484000e+03
# mean   2005.000000  7.909678e+11        6.264477e+07
# std       7.790449  1.984299e+12        1.834772e+08
# min    1992.000000  0.000000e+00        2.601550e+05
# 25%    1998.000000  6.144881e+10        5.074450e+06
# 50%    2005.000000  2.248733e+11        1.540440e+07
# 75%    2012.000000  6.050548e+11        4.884866e+07
# max    2018.000000  1.815162e+13        1.427648e+09
#
#        Emissions.Production.CH4  Emissions.Production.N2O  \
# count               2484.000000               2484.000000
# mean                  71.834473                 24.555829
# std                  150.453654                 58.642876
# min                    0.520000                  0.110000
# 25%                    7.460000                  2.550000
# 50%                   22.835000                  7.490000
# 75%                   66.032500                 21.882500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Year                                2484 non-null   int64
#  1   Country.Name                        2484 non-null   object
#  2   Country.Code                        2484 non-null   object
#  3   Country.GDP                         2484 non-null   float64
#  4   Country.Population                  2484 non-null   int64
#  5   Emissions.Production.CH4            2484 non-null   float64
#  6   Emissions.Production.N2O            2484 non-null   float64
#  7   Emissions.Production.CO2.Cement     2484 non-null   float64
#  8   Emissions.Production.CO2.Coal       2484 non-null   float64
#  9   Emissions.Production.CO2.Gas        2484 non-null   float64
#  10  Emissions.Production.CO2.Oil        2484 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Country.Name', 'Country.Code', 'Country.GDP',
#        'Country.Population', 'Emissions.Production.CH4',
#        'Emissions.Production.N2O', 'Emissions.Production.CO2.Cement',
#        'Emissions.Production.CO2.Coal', 'Emissions.Production.CO2.Gas',
#        'Emissions.Production.CO2.Oil', 'Emissions.Production.CO2.Flaring',
#        'Emissions.Production.CO2.Other', 'Emissions.Production.CO2.Total',
#        'Emissions.Global Share.CO2.Cement', 'Emissions.Global Share.CO2.Coal',
#        'Emissions.Global Share.CO2.Gas', 'Emissions.Global Share.CO2.Oil',
#        'Emissions.Global Share.CO2.Flaring',
#        'Emissions.Global Share.CO2.Total'],
#       dtype='object')

# %%
df['Emissions.Production.CH4'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Emissions.Production.N2O'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Emissions.Production.CO2.Cement'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Emissions.Production.CO2.Coal'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Emissions.Production.CO2.Coal'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Emissions.Production.CO2.Gas'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Emissions.Production.CO2.Oil'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Emissions.Production.CO2.Flaring'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Emissions.Production.CO2.Total'].plot(kind='box')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(4,6))
plt.title('Global Emissions')
plt.bar(['Year'],df['Emissions.Production.CH4'].value_counts() , edgecolor='k', width=0.3)
plt.show()

# %%
plt.figure(figsize = (20,8))
axl = sns.countplot(x = 'Year', hue = 'Year',data = df)
plt.title('Country Population', size = 20)
plt.xlabel('Year')
plt.ylabel('Country.Population')
plt.show()

# %%
import matplotlib.pyplot as plt

x_positions = df['Year']
bar_heights_1 = df['Emissions.Production.CH4']
bar_heights_2 = df['Emissions.Production.N2O']
bar_heights_3 = df['Emissions.Production.N2O']


# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10,4))

# Plot 1
axes[0].bar(x_positions, bar_heights_1, color='blue', edgecolor = 'k')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Emissions.Production.CH4')
axes[0].set_title('CH4 Emissions Production', size= 10)

# Plot 2
axes[1].bar(x_positions, bar_heights_2, color='green', edgecolor = 'k')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Emissions.Production.N2O')
axes[1].set_title('N2O Emissions Production', size= 10)

# Plot 3
axes[2].bar(x_positions, bar_heights_3, color='red', edgecolor = 'k')
axes[2].set_xlabel('Year')
axes[2].set_ylabel('Emissions.Production.CO2.Cement')
axes[2].set_title('CO2 Cement Emissions Production', size= 10)


# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

x_positions = df['Year']
bar_heights_1 = df['Emissions.Production.CO2.Coal']
bar_heights_2 = df['Emissions.Production.CO2.Gas']
bar_heights_3 = df['Emissions.Production.CO2.Oil']

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10,4))

#Plot 1
axes[0].bar(x_positions, bar_heights_1, color='purple', edgecolor = 'k')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Emissions.Production.CO2.Coal')
axes[0].set_title('CO2 Coal Emissions Production', size= 10)

# Plot 2
axes[1].bar(x_positions, bar_heights_2, color='orange', edgecolor = 'k')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Emissions.Production.CO2.Gas')
axes[1].set_title('CO2 Gas Emissions Production', size= 10)

# Plot 3
axes[2].bar(x_positions, bar_heights_3, color='pink', edgecolor = 'k')
axes[2].set_xlabel('Year')
axes[2].set_ylabel('Emissions.Production.CO2.Oil')
axes[2].set_title('CO2 Oil Emissions Production', size= 10)

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

x_positions = df['Year']
bar_heights_1 = df['Emissions.Production.CO2.Flaring']
bar_heights_2 = df['Emissions.Production.CO2.Other']
bar_heights_3 = df['Emissions.Production.CO2.Total']

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10,4))

# Plot 1
axes[0].bar(x_positions, bar_heights_1, color='blue', edgecolor = 'k')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Emissions.Production.CO2.Flaring')
axes[0].set_title('CO2 Flaring Production', size= 10)

# Plot 2
axes[1].bar(x_positions, bar_heights_2, color='green', edgecolor = 'k')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Emissions.Production.CO2.Other')
axes[1].set_title('Other CO2 Emissions Production', size= 10)

# Plot 3
axes[2].bar(x_positions, bar_heights_3, color='red', edgecolor = 'k')
axes[2].set_xlabel('Year')
axes[2].set_ylabel('Emissions.Production.CO2.Total')
axes[2].set_title('Total CO2 Emissions Production', size= 10)


# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

x_positions = df['Country.Name']
bar_heights_1 = df['Emissions.Production.CH4']
bar_heights_2 = df['Emissions.Production.N2O']

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

# Plot 1
axes[0].bar(x_positions, bar_heights_1, color='blue', edgecolor = 'k')
axes[0].set_xlabel('Country.Name')
axes[0].set_ylabel('Emissions.Production.CH4')
axes[0].set_title('CH4 Emissions Production', size= 10)

# Plot 2
axes[1].bar(x_positions, bar_heights_2, color='green', edgecolor = 'k')
axes[1].set_xlabel('Country.Name')
axes[1].set_ylabel('Emissions.Production.N2O')
axes[1].set_title('N2O Emissions Production', size= 10)


# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

x_positions = df['Country.Name']
bar_heights_1 = df['Emissions.Production.CO2.Cement']
bar_heights_2 = df['Emissions.Production.CO2.Coal']

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

# Plot 1
axes[0].bar(x_positions, bar_heights_1, color='red', edgecolor = 'k')
axes[0].set_xlabel('Country.Name')
axes[0].set_ylabel('Emissions.Production.CO2.Cement')
axes[0].set_title('CO2 Cement Emissions Production', size= 10)

#Plot 2
axes[1].bar(x_positions, bar_heights_2, color='purple', edgecolor = 'k')
axes[1].set_xlabel('Country.Name')
axes[1].set_ylabel('Emissions.Production.CO2.Coal')
axes[1].set_title('CO2 Coal Emissions Production', size= 10)

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

x_positions = df['Country.Name']
bar_heights_1 = df['Emissions.Production.CO2.Gas']
bar_heights_2 = df['Emissions.Production.CO2.Oil']
bar_heights_3 = df['Emissions.Production.CO2.Flaring']

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10,4))

# Plot 1
axes[0].bar(x_positions, bar_heights_1, color='orange', edgecolor = 'k')
axes[0].set_xlabel('Country.Name')
axes[0].set_ylabel('Emissions.Production.CO2.Gas')
axes[0].set_title('CO2 Gas Emissions Production', size= 10)

# Plot 2
axes[1].bar(x_positions, bar_heights_2, color='pink', edgecolor = 'k')
axes[1].set_xlabel('Country.Name')
axes[1].set_ylabel('Emissions.Production.CO2.Oil')
axes[1].set_title('CO2 Oil Emissions Production', size= 10)

# Plot 3
axes[2].bar(x_positions, bar_heights_3, color='violet', edgecolor = 'k')
axes[2].set_xlabel('Country.Name')
axes[2].set_ylabel('Emissions.Production.CO2.Flaring')
axes[2].set_title('CO2 Flaring Cement Emissions Production', size= 10)


# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

x_positions = df['Country.Name']
bar_heights_1 = df['Emissions.Production.CO2.Other']
bar_heights_2 = df['Emissions.Production.CO2.Total']

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

# Plot 1
axes[0].bar(x_positions, bar_heights_1, color='#5FD93B', edgecolor = 'k')
axes[0].set_xlabel('Country.Name')
axes[0].set_ylabel('Emissions.Production.CO2.Other')
axes[0].set_title('CO2 Other Cement Emissions Production', size= 10)

# Plot 2
axes[1].bar(x_positions, bar_heights_2, color='#D95065', edgecolor = 'k')
axes[1].set_xlabel('Country.Name')
axes[1].set_ylabel('Emissions.Production.CO2.Total')
axes[1].set_title('Total CO2 Emissions Production', size= 10)

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

x_positions = df['Year']
bar_heights_1 = df['Emissions.Production.CH4']
bar_heights_2 = df['Emissions.Production.N2O']
bar_heights_3 = df['Emissions.Production.CO2.Cement']
bar_heights_4 = df['Emissions.Production.CO2.Coal']
bar_heights_5 = df['Emissions.Production.CO2.Gas']
bar_heights_6 = df['Emissions.Production.CO2.Oil']
bar_heights_7 = df['Emissions.Production.CO2.Flaring']
bar_heights_8 = df['Emissions.Production.CO2.Other']
bar_heights_9 = df['Emissions.Production.CO2.Total']

# Create subplots
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(20,6))

# Plot 1
axes[0,0].bar(x_positions, bar_heights_1, color='blue', edgecolor = 'k')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Emissions.Production.CH4')
axes[0,0].set_title('CH4 Emissions Production', size= 10)

# Plot 2
axes[0,1].bar(x_positions, bar_heights_2, color='green', edgecolor = 'k')
axes[0,1].set_xlabel('Year')
axes[0,1].set_ylabel('Emissions.Production.N2O')
axes[0,1].set_title('N2O Emissions Production', size= 10)

# Plot 3
axes[0,2].bar(x_positions, bar_heights_3, color='red', edgecolor = 'k')
axes[0,2].set_xlabel('Year')
axes[0,2].set_ylabel('Emissions.Production.CO2.Cement')
axes[0,2].set_title('CO2 Cement Emissions Production', size= 10)

#Plot 4
axes[1,0].bar(x_positions, bar_heights_4, color='purple', edgecolor = 'k')
axes[1,0].set_xlabel('Year')
axes[1,0].set_ylabel('Emissions.Production.CO2.Coal')
axes[1,0].set_title('CO2 Coal Emissions Production', size= 10)

# Plot 5
axes[1,1].bar(x_positions, bar_heights_5, color='orange', edgecolor = 'k')
axes[1,1].set_xlabel('Year')
axes[1,1].set_ylabel('Emissions.Production.CO2.Gas')
axes[1,1].set_title('CO2 Gas Emissions Production', size= 10)

# Plot 6
axes[1,2].bar(x_positions, bar_heights_6, color='pink', edgecolor = 'k')
axes[1,2].set_xlabel('Year')
axes[1,2].set_ylabel('Emissions.Production.CO2.Oil')
axes[1,2].set_title('CO2 Oil Emissions Production', size= 10)

# Plot 7
axes[2,0].bar(x_positions, bar_heights_7, color='violet', edgecolor = 'k')
axes[2,0].set_xlabel('Year')
axes[2,0].set_ylabel('Emissions.Production.CO2.Flaring')
axes[2,0].set_title('CO2 Flaring Cement Emissions Production', size= 10)

# Plot 8
axes[2,1].bar(x_positions, bar_heights_8, color='#5FD93B', edgecolor = 'k')
axes[2,1].set_xlabel('Year')
axes[2,1].set_ylabel('Emissions.Production.CO2.Other')
axes[2,1].set_title('CO2 Other Cement Emissions Production', size= 10)

# Plot 9
axes[2,2].bar(x_positions, bar_heights_9, color='#D95065', edgecolor = 'k')
axes[2,2].set_xlabel('Year')
axes[2,2].set_ylabel('Emissions.Production.CO2.Total')
axes[2,2].set_title('Total CO2 Emissions Production', size= 10)

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

x_positions = df['Country.Name']
bar_heights_1 = df['Emissions.Production.CH4']
bar_heights_2 = df['Emissions.Production.N2O']
bar_heights_3 = df['Emissions.Production.CO2.Cement']
bar_heights_4 = df['Emissions.Production.CO2.Coal']
bar_heights_5 = df['Emissions.Production.CO2.Gas']
bar_heights_6 = df['Emissions.Production.CO2.Oil']
bar_heights_7 = df['Emissions.Production.CO2.Flaring']
bar_heights_8 = df['Emissions.Production.CO2.Other']
bar_heights_9 = df['Emissions.Production.CO2.Total']

font= {'family':'Arial', 'color':'black', 'size':'8'}
# Create subplots
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(220,40))

# Plot 1
axes[0,0].bar(x_positions, bar_heights_1, color='blue', edgecolor = 'k')
axes[0,0].set_xlabel('Country.Name', fontdict= font)
axes[0,0].set_ylabel('Emissions.Production.CH4')
axes[0,0].set_title('CH4 Emissions Production', size= 10)

# Plot 2
axes[0,1].bar(x_positions, bar_heights_2, color='green', edgecolor = 'k')
axes[0,1].set_xlabel('Country.Name', fontdict= font)
axes[0,1].set_ylabel('Emissions.Production.N2O')
axes[0,1].set_title('N2O Emissions Production', size= 10)

# Plot 3
axes[0,2].bar(x_positions, bar_heights_3, color='red', edgecolor = 'k')
axes[0,2].set_xlabel('Country.Name', fontdict= font)
axes[0,2].set_ylabel('Emissions.Production.CO2.Cement')
axes[0,2].set_title('CO2 Cement Emissions Production', size= 10)

#Plot 4
axes[1,0].bar(x_positions, bar_heights_4, color='purple', edgecolor = 'k')
axes[1,0].set_xlabel('Country.Name', fontdict= font)
axes[1,0].set_ylabel('Emissions.Production.CO2.Coal')
axes[1,0].set_title('CO2 Coal Emissions Production', size= 10)

# Plot 5
axes[1,1].bar(x_positions, bar_heights_5, color='orange', edgecolor = 'k')
axes[1,1].set_xlabel('Country.Name', fontdict= font)
axes[1,1].set_ylabel('Emissions.Production.CO2.Gas')
axes[1,1].set_title('CO2 Gas Emissions Production', size= 10)

# Plot 6
axes[1,2].bar(x_positions, bar_heights_6, color='pink', edgecolor = 'k')
axes[1,2].set_xlabel('Country.Name', fontdict= font)
axes[1,2].set_ylabel('Emissions.Production.CO2.Oil')
axes[1,2].set_title('CO2 Oil Emissions Production', size= 10)

# Plot 7
axes[2,0].bar(x_positions, bar_heights_7, color='violet', edgecolor = 'k')
axes[2,0].set_xlabel('Country.Name', fontdict= font)
axes[2,0].set_ylabel('Emissions.Production.CO2.Flaring')
axes[2,0].set_title('CO2 Flaring Cement Emissions Production', size= 10)

# Plot 8
axes[2,1].bar(x_positions, bar_heights_8, color='#5FD93B', edgecolor = 'k')
axes[2,1].set_xlabel('Country.Name', fontdict= font)
axes[2,1].set_ylabel('Emissions.Production.CO2.Other')
axes[2,1].set_title('CO2 Other Cement Emissions Production', size= 10)

# Plot 9
axes[2,2].bar(x_positions, bar_heights_9, color='#D95065', edgecolor = 'k')
axes[2,2].set_xlabel('Country.Name', fontdict= font)
axes[2,2].set_ylabel('Emissions.Production.CO2.Total')
axes[2,2].set_title('Total CO2 Emissions Production', size= 10)

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

x_positions = df['Year']
bar_heights_1 = df['Emissions.Global Share.CO2.Cement']
bar_heights_2 = df['Emissions.Global Share.CO2.Coal']
bar_heights_3 = df['Emissions.Global Share.CO2.Gas']
bar_heights_4 = df['Emissions.Global Share.CO2.Oil']
bar_heights_5 = df['Emissions.Global Share.CO2.Flaring']
bar_heights_6 = df['Emissions.Global Share.CO2.Total']

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20,6))

# Plot 1
axes[0,0].bar(x_positions, bar_heights_1, color='blue', edgecolor = 'k')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Emissions.Global Share.CO2.Cement')
axes[0,0].set_title('Emissions.Global Share of CO2 Cement', size= 10)

# Plot 2
axes[0,1].bar(x_positions, bar_heights_2, color='green', edgecolor = 'k')
axes[0,1].set_xlabel('Year')
axes[0,1].set_ylabel('Emissions.Global Share.CO2.Coal')
axes[0,1].set_title('Emissions.Global Share of CO2 Coal', size= 10)

# Plot 3
axes[0,2].bar(x_positions, bar_heights_3, color='red', edgecolor = 'k')
axes[0,2].set_xlabel('Year')
axes[0,2].set_ylabel('Emissions.Global Share.CO2.Gas')
axes[0,2].set_title('Emissions.Global Share of CO2 Gas', size= 10)

#Plot 4
axes[1,0].bar(x_positions, bar_heights_4, color='purple', edgecolor = 'k')
axes[1,0].set_xlabel('Year')
axes[1,0].set_ylabel('Emissions.Global Share.CO2.Oil')
axes[1,0].set_title('Emissions.Global Share of CO2 Oil', size= 10)

# Plot 5
axes[1,1].bar(x_positions, bar_heights_5, color='orange', edgecolor = 'k')
axes[1,1].set_xlabel('Year')
axes[1,1].set_ylabel('Emissions.Global Share.CO2.Flaring')
axes[1,1].set_title('Emissions.Global Share of CO2 Flaring', size= 10)

# Plot 6
axes[1,2].bar(x_positions, bar_heights_6, color='#D95065', edgecolor = 'k')
axes[1,2].set_xlabel('Year')
axes[1,2].set_ylabel('Emissions.Global Share.CO2.Total')
axes[1,2].set_title('Emissions.Global Share of CO2 Total', size= 10)


# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

x_positions = df['Country.Name']
bar_heights_1 = df['Emissions.Global Share.CO2.Cement']
bar_heights_2 = df['Emissions.Global Share.CO2.Coal']
bar_heights_3 = df['Emissions.Global Share.CO2.Gas']
bar_heights_4 = df['Emissions.Global Share.CO2.Oil']
bar_heights_5 = df['Emissions.Global Share.CO2.Flaring']
bar_heights_6 = df['Emissions.Global Share.CO2.Total']

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(220,40))

# Plot 1
axes[0,0].bar(x_positions, bar_heights_1, color='blue', edgecolor = 'k')
axes[0,0].set_xlabel('Country.Name')
axes[0,0].set_ylabel('Emissions.Global Share.CO2.Cement')
axes[0,0].set_title('Emissions.Global Share of CO2 Cement', size= 10)

# Plot 2
axes[0,1].bar(x_positions, bar_heights_2, color='green', edgecolor = 'k')
axes[0,1].set_xlabel('Country.Name')
axes[0,1].set_ylabel('Emissions.Global Share.CO2.Coal')
axes[0,1].set_title('Emissions.Global Share of CO2 Coal', size= 10)

# Plot 3
axes[0,2].bar(x_positions, bar_heights_3, color='red', edgecolor = 'k')
axes[0,2].set_xlabel('Country.Name')
axes[0,2].set_ylabel('Emissions.Global Share.CO2.Gas')
axes[0,2].set_title('Emissions.Global Share of CO2 Gas', size= 10)

#Plot 4
axes[1,0].bar(x_positions, bar_heights_4, color='purple', edgecolor = 'k')
axes[1,0].set_xlabel('Country.Name')
axes[1,0].set_ylabel('Emissions.Global Share.CO2.Oil')
axes[1,0].set_title('Emissions.Global Share of CO2 Oil', size= 10)

# Plot 5
axes[1,1].bar(x_positions, bar_heights_5, color='orange', edgecolor = 'k')
axes[1,1].set_xlabel('Country.Name')
axes[1,1].set_ylabel('Emissions.Global Share.CO2.Flaring')
axes[1,1].set_title('Emissions.Global Share of CO2 Flaring', size= 10)

# Plot 6
axes[1,2].bar(x_positions, bar_heights_6, color='#D95065', edgecolor = 'k')
axes[1,2].set_xlabel('Country.Name')
axes[1,2].set_ylabel('Emissions.Global Share.CO2.Total')
axes[1,2].set_title('Emissions.Global Share of CO2 Total', size= 10)


# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
